# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %% [markdown]
# Criando o Dataframe inical do Vestibular:

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'assunto': ['Matematica', 'Portugues', 'Geografia', 'Ingles', 'Historia', 'Fisica', 'Quimica'], \
                  'numero de questoes': [24, 18, 8, 8, 8, 12, 12 ]})
df
# Out:
#       assunto  numero de questoes
# 0  Matematica                  24
# 1   Portugues                  18
# 2   Geografia                   8
# 3      Ingles                   8
# 4    Historia                   8
# 5      Fisica                  12
# 6     Quimica                  12

# %%
np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
# Porcentagem por assunto:

mat = (df_mat['Qt_acertos'] / df.iloc[0, 1]) * 100
por = (df_por['Qt_acertos'] / df.iloc[1, 1]) * 100
geo = (df_geo['Qt_acertos'] / df.iloc[2, 1]) * 100
ing = (df_ing['Qt_acertos'] / df.iloc[3, 1]) * 100
his = (df_his['Qt_acertos'] / df.iloc[4, 1]) * 100
fis = (df_fis['Qt_acertos'] / df.iloc[5, 1]) * 100
qui = (df_qui['Qt_acertos'] / df.iloc[6, 1]) * 100

# %%
# 2) Seu código aqui
# Acertos de cada aluno:
acertos_aluno = df_fis + df_geo + df_his + df_ing + df_mat + df_por + df_qui
acertos_aluno
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
# Percentual de cada aluno:
acertos_aluno['Percent_Total'] = (acertos_aluno['Qt_acertos'] / df["numero de questoes"].sum()) * 100
acertos_aluno
# Out:
#     Qt_acertos  Percent_Total
# 0           35      38.888889
# 1           48      53.333333
# 2           50      55.555556
# 3           32      35.555556
# 4           30      33.333333
# ..         ...            ...
# 95          34      37.777778
# 96          27      30.000000
# 97          40      44.444444
# 98          40      44.444444
# 99          42      46.666667
#
# [100 rows x 2 columns]

# %%
# 4) Seu código aqui
# Contando quantos alunos tiveram 45 pontos ou mais:
corte = acertos_aluno['Qt_acertos'] >= 45
pre_aprovados = corte.sum()
pre_aprovados
# Out:
# 34

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
# Alunos desqualificados pelo critério de zeramento: 
criterio = (df_mat['Qt_acertos'] == 0) | (df_fis["Qt_acertos"] == 0) | (df_qui['Qt_acertos'] == 0)
df_reprovados = pd.DataFrame({'Reprovados': criterio})
df_reprovados = df_reprovados[df_reprovados['Reprovados']]
df_reprovados
# Out:
#     Reprovados
# 3         True
# 6         True
# 10        True
# 12        True
# 14        True
# 20        True
# 25        True
# 26        True
# 27        True
# 33        True
# 35        True
# 49        True
# 56        True
# 65        True
# 66        True
# 72        True
# 73        True
# 74        True
# 84        True
# 89        True
# 92        True
# 94        True
# 98        True

# %%
# Contagem de reprovados:
df_reprovados.sum()
# Out:
# Reprovados    23
# dtype: int64

# %%
# Média desses alunos em História e Geografia:
df_reprovados['Media_his_geo'] = (df_geo.loc[df_reprovados.index] + df_his.loc[df_reprovados.index]).mean(axis=1)
df_reprovados
# Out:
#     Reprovados  Media_his_geo
# 3         True            3.0
# 6         True           12.0
# 10        True            4.0
# 12        True            4.0
# 14        True            2.0
# 20        True           12.0
# 25        True            7.0
# 26        True           13.0
# 27        True            8.0
# 33        True            6.0
# 35        True            9.0
# 49        True            2.0
# 56        True           13.0
# 65        True            5.0
# 66        True            6.0
# 72        True           10.0
# 73        True            5.0
# 74        True            5.0
# 84        True            1.0
# 89        True           13.0
# 92        True            2.0
# 94        True            3.0
# 98        True            8.0

# %%
# Aprovados para a segunda fase:
aprovados = criterio[corte]
aprovados = aprovados[aprovados].index
pd.DataFrame({'Aprovados': aprovados})

# Somente 5 alunos atendem aos dois critérios
# Out:
#    Aprovados
# 0         20
# 1         27
# 2         35
# 3         72
# 4         89

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
df_sus = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-f01336d5-5504-4b98-94e0-9d5aba96f91a.c000.csv', sep=';')
df_sus.head(5)
# Out:
#                                  document_id  \
# 0  0136034c-5d08-454d-bcf7-f2640c9900af-i0b0
# 1  28bcb231-f9b8-4315-9da2-17748d548d69-i0b0
# 2  7c0e200d-2e96-4c6e-9a8e-d3c4a24a577f-i0b0
# 3  28e42d7e-bc1a-4628-9485-e3d610e25f35-i0b0
# 4  c35b981b-afe0-4600-b2bb-66ccac2e4bb3-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  f74a177a923f4882fabd3fc25029b2804fa5316d8f47e5...              41
# 1  0460d42f66dd82c825664fd3ca34c62fa0adf1f54fa4ec...              30
# 2  bd752fe1fb6512068a7e427506b259bea1d7418b516a6a...              55
# 3  d8d6be00190f654367b2642b0fd147d023e40df8d1089a...               8
# 4  3408e159c4899f96b9808ebe78e56b73bca22b230733e0...              34
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1980-07-22                          F                        3
# 1              1991-04-05                          M                        3
# ...

# %%
# 1) Sua solução aqui
# Quantidade de registros:
df_sus.shape[0]
# Out:
# 384920

# %%
# 2) Quantidade de vacinados:
df_sus['paciente_id'].nunique()
# Out:
# 314987

# %%
# 3) Quantidade de pacientes que tomaram a primeira dose: 
primeira_dose = df_sus['vacina_descricao_dose'].unique()[0]
df_sus['paciente_id'].loc[df_sus['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 72006

# %%
# 3) solução alternativa
primeira_dose = df_sus['vacina_descricao_dose'].unique()[0]
df_primeira_dose = df_sus[df_sus['vacina_descricao_dose'] == primeira_dose]
df_primeira_dose['paciente_id'].nunique()
# Out:
# 72006

# %%
# 4) Menores de 18 anos vacinados:
df_menores = df_sus[df_sus['paciente_idade'] < 18]
df_menores['paciente_id'].nunique()
# Out:
# 67143

# %%
# 5) Quantidade de estabelecimentos que aplicaram a vacina:
df_sus['estabelecimento_razaoSocial'].nunique()
# Out:
# 61

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) Vacinas aplicadas a menores de 18 anos:
df_menores = df_sus[df_sus['paciente_idade'] < 18].copy()
df_menores
# Out:
#                                       document_id  \
# 3       28e42d7e-bc1a-4628-9485-e3d610e25f35-i0b0
# 16      6871f196-1a3a-4cda-b973-9b620e5c9a6a-i0b0
# 17      29fb8135-a3bb-4b3c-88f6-99b4fe529f52-i0b0
# 20      a8653b73-75a7-4d58-92f6-846f1ab48980-i0b0
# 22      c4fe1c06-9d03-4fb3-9f09-d03ae04172ed-i0b0
# ...                                           ...
# 384891  8a7d37de-45a6-425e-9889-2342f5f71ab7-i0b0
# 384894  8ac9edc6-e290-42e5-ab8e-6d8ac3fbfd33-i0b0
# 384898  8afa7a22-e1e8-4d65-9613-e0480e99a8fc-i0b0
# 384906  8b9c67db-7e78-4eff-8542-c49816a2597a-i0b0
# 384914  8c301eca-0286-4f3b-bfaa-7dfa15263373-i0b0
#
#                                               paciente_id  paciente_idade  \
# 3       d8d6be00190f654367b2642b0fd147d023e40df8d1089a...               8
# 16      92025867c1bfdead367b87461091ae2f5619383ac10777...               6
# 17      48ce0564d76a491ae41c2f1e13d2bc5cdcf7400912221c...              14
# ...

# %%
# 2) Lista de colunas deste Dataframe:
colunas = df_menores.columns
colunas
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3) Contando o campo vacina_categoria_nome:
df_menores['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      46438
# Povos Indígenas                                    4496
# Outros                                             3755
# Povos e Comunidades Tradicionais                    811
# Trabalhadores de Saúde                              248
# Comorbidades                                         56
# População Privada de Liberdade                       53
# Gestantes                                            42
# Pessoas com Deficiência                              11
# Pessoas Institucionalizadas                           3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Puérperas                                             1
# Trabalhadores da Educação                             1
# Name: count, dtype: int64

# %%
# 4) Lista de variáveis:
lista_variáveis = ['estabelecimento_valor', 'estabelecimento_razaoSocial', 'estalecimento_noFantasia', 
                  'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome', 'estabelecimento_uf']
df_lista = df_menores.loc[:, lista_variáveis]
df_lista
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 3                     5981891  PREFEITURA MUNICIIPAL DE SENA MADUREIRA
# 16                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 17                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 20                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 22                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                       ...                                      ...
# 384891                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 384894                2000873   PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 384898                2001217           PREFEITURA MUNICIPAL DE XAPURI
# 384906                6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 384914                5981891  PREFEITURA MUNICIIPAL DE SENA MADUREIRA
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 5) drp_duplicates
df_lista = df_menores.drop_duplicates()
df_lista.shape
# Out:
# (75846, 32)
